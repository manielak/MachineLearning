# %% [markdown]
# # Import libraries and data

# %%
import pandas as pd
import numpy as np
import qgrid
import eli5

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, GroupKFold
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit


import xgboost as xgb
import catboost as ctb


np.random.seed(0)

# %%
df_train = pd.read_hdf("../input/energy_train.h5")
df_test = pd.read_hdf("../input/energy_test.h5")
df_train["date"] = pd.to_datetime(df_train["date"], format = '%d/%m/%Y')
df_test["date"] = pd.to_datetime(df_test["date"], format = '%d/%m/%Y')

df_all = pd.concat([df_train, df_test])
df_all["date"] = pd.to_datetime(df_all["date"])

df_all.shape
# Out:
# (35252, 3)

# %% [markdown]
# # Feature engineering

# %%
def feature_engineering(df, d):
    df["day"] = df["date"].dt.day
    df["month"] = df["date"].dt.month
    df["hour"] = df["date"].dt.hour
    df["year"] = df["date"].dt.year
    df["week"] = df["date"].dt.week
    df["dayofweek"] = df["date"].dt.dayofweek
    df["dayofyear"] = df["date"].dt.dayofyear
    df["quarter"]=df["date"].dt.quarter    
    df["weekofyear"] = df["date"].dt.weekofyear   
    
    
    df.index = df["date"]
    df_train = df[ df.value.notnull() ]
    
    #get value from yesterday 
    #d = 1
    df_train_new = df_train.copy()
    feat_name = "dayofyear_{}d".format(d)
    value_feat_name = "value_{}dayofyear".format(d)

    df_train_new[feat_name] = df_train_new["dayofyear"] - d
    df_train_new.rename(columns={"value": value_feat_name}, inplace=True)
    
    df = pd.merge(df, df_train_new[ [value_feat_name, feat_name, "year", "hour"] ], left_on=["year", "dayofyear", "hour"], right_on=["year", feat_name, "hour"], how="left")
#     df = pd.merge(df, df_train_new2[ [value_feat_name2, feat_name2, "week", "hour"] ], left_on=["week", "dayofweek", "hour"], right_on=["week", feat_name2, "hour"], how="left")
#     ####
    
    
    
    return df
    
df_all = feature_engineering(df_all, 1)

# %%
df_all = feature_engineering(df_all, 7)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35252 entries, 0 to 35251
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                35252 non-null  int64
#  1   date              35252 non-null  datetime64[ns]
#  2   value             26517 non-null  float64
#  3   day               35252 non-null  int64
#  4   month             35252 non-null  int64
#  5   hour              35252 non-null  int64
#  6   year              35252 non-null  int64
#  7   week              35252 non-null  int64
#  8   dayofweek         35252 non-null  int64
#  9   dayofyear         35252 non-null  int64
#  10  quarter           35252 non-null  int64
#  11  weekofyear        35252 non-null  int64
#  12  value_1dayofyear  26418 non-null  float64
#  13  dayofyear_1d      26418 non-null  float64
#  14  value_7dayofyear  25915 non-null  float64
#  15  dayofyear_7d      25915 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(10)
# memory usage: 4.6 MB

# %%
business_hours = [9, 10, 11, 12, 13, 14, 15, 16, 17]
df_all["business_hour"]=df_all["hour"].map(lambda x: 1 if x in business_hours else 0)

# %%
df_all["hour_month"] = df_all.apply(lambda x: "{}-{}".format(x["hour"], x["month"]), axis=1)
df_all["hour_day"] = df_all.apply(lambda x: "{}-{}".format(x["hour"], x["day"]), axis=1)
df_all["hour_day_of_week"] = df_all.apply(lambda x: "{}-{}".format(x["hour"], x["dayofweek"]), axis=1)
df_all["hour_day_of_week_month"] = df_all.apply(lambda x: "{}-{}".format(x["hour_day_of_week"], x["month"]), axis=1)
# df_all["business_hour_day_of_week"] = df_all.apply(lambda x: "{}-{}".format(x["business_hour"], x["day_of_week"]), axis=1)

# %%
df_all["hour_month_cat"] = df_all["hour_month"].factorize()[0]
df_all["hour_day_cat"] = df_all["hour_day"].factorize()[0]
df_all["hour_day_of_week_cat"] = df_all["hour_day_of_week"].factorize()[0]
df_all["hour_day_of_week_month_cat"] = df_all["hour_day_of_week_month"].factorize()[0]
# df_all["business_hour_day_of_week_cat"] = df_all["business_hour_day_of_week"].factorize()[0]

# %%
def df_group_delay(df_train, groupby_feats):
    agg_params = {
        "mean_{}_value".format("_".join(groupby_feats)): ("value", "mean"),
        "median_{}_value".format("_".join(groupby_feats)): ("value", "median"),
        #"count_{}_value".format("_".join(groupby_feats)): ("value", "count"),
        #"std_{}_value".format("_".join(groupby_feats)): ("value", "std"),
        #"count_zeros_{}_value".format("_".join(groupby_feats)): ("value", lambda vals: len([x for x in vals if x == 0]) ),
        #"prob_zeros_{}_value".format("_".join(groupby_feats)): ("value", lambda vals: np.mean([x == 0 for x in vals]) ),
    }
    
    return df_train[groupby_feats + ["value"]].groupby(groupby_feats).agg(
        **agg_params
    ).reset_index()

# df_tmp = df_group_delay(df_train, ["hour"])
# if "mean_hour_value" not in df_all:
#     df_all = pd.merge(df_all, df_tmp, on="hour", how="left")

df_tmp = df_group_delay(df_all, ["hour_day_of_week_month"])
if "mean_hour_day_of_week_month_value" not in df_all:
    df_all = pd.merge(df_all, df_tmp, on="hour_day_of_week_month", how="left")
    
df_tmp = df_group_delay(df_all, ["value_1dayofyear"])
if "mean_value_1dayofyear_value" not in df_all:
    df_all = pd.merge(df_all, df_tmp, on="value_1dayofyear", how="left")

df_tmp = df_group_delay(df_all, ["value_7dayofyear"])
if "mean_value_7dayofyear_value" not in df_all:
    df_all = pd.merge(df_all, df_tmp, on="value_7dayofyear", how="left")

# df_tmp = df_group_delay(df_all, ["hour_month"])
# if "mean_hour_month_value" not in df_all:
#     df_all = pd.merge(df_all, df_tmp, on="hour_month", how="left" )
    
# df_tmp = df_group_delay(df_all, ["hour_day_of_week"])
# if "mean_hour_day_of_week_value" not in df_all:
#     df_all = pd.merge(df_all, df_tmp, on="hour_day_of_week", how="left" )

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35252 entries, 0 to 35251
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   35252 non-null  int64
#  1   date                                 35252 non-null  datetime64[ns]
#  2   value                                26517 non-null  float64
#  3   day                                  35252 non-null  int64
#  4   month                                35252 non-null  int64
#  5   hour                                 35252 non-null  int64
#  6   year                                 35252 non-null  int64
#  7   week                                 35252 non-null  int64
#  8   dayofweek                            35252 non-null  int64
#  9   dayofyear                            35252 non-null  int64
#  10  quarter                              35252 non-null  int64
#  11  weekofyear                           35252 non-null  int64
#  12  value_1dayofyear                     26418 non-null  float64
#  13  dayofyear_1d                         26418 non-null  float64
#  14  value_7dayofyear                     25915 non-null  float64
#  15  dayofyear_7d                         25915 non-null  float64
#  16  business_hour                        35252 non-null  int64
#  17  hour_month                           35252 non-null  object
#  18  hour_day                             35252 non-null  object
#  19  hour_day_of_week                     35252 non-null  object
#  20  hour_day_of_week_month               35252 non-null  object
#  21  hour_month_cat                       35252 non-null  int64
#  22  hour_day_cat                         35252 non-null  int64
#  23  hour_day_of_week_cat                 35252 non-null  int64
#  24  hour_day_of_week_month_cat           35252 non-null  int64
#  25  mean_hour_day_of_week_month_value    35252 non-null  float64
#  26  median_hour_day_of_week_month_value  35252 non-null  float64
#  27  mean_value_1dayofyear_value          20200 non-null  float64
#  28  median_value_1dayofyear_value        20200 non-null  float64
#  29  mean_value_7dayofyear_value          19659 non-null  float64
#  30  median_value_7dayofyear_value        19659 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(15), object(4)
# memory usage: 8.6+ MB

# %%
# group_features = {
#         "group_mean_hour_dayofweek": ["hour", "dayofweek"],
#         "group_mean_hour_month": ["hour", "month"],
#         "group_mean_hour_dayofweek_month": ["hour", "dayofweek", "month"],
#     }
    

#     for feat_name,group_keys in group_features.items(): 
#         dict_group = {k:v["value"] for k,v in df_train[["value"] + group_keys].groupby(group_keys).agg("mean").to_dict(orient="items").items() }
#         df[feat_name] = df[ group_keys ].apply(lambda keys: dict_group.get(tuple(keys)), axis=1)

# %%
qgrid.show_grid(df_all, show_toolbar=True)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df_all.corr("pearson")
# Out:
#                                            id     value       day     month  \
# id                                   1.000000  0.106168  0.004767  0.033852
# value                                0.106168  1.000000  0.029687 -0.023231
# day                                  0.004767  0.029687  1.000000  0.017658
# month                                0.033852 -0.023231  0.017658  1.000000
# hour                                 0.000610  0.500412  0.000269 -0.000192
# year                                 0.969923  0.107406 -0.019940 -0.209583
# week                                 0.042208 -0.030478  0.070373  0.966367
# dayofweek                           -0.001706 -0.333319  0.004364 -0.004219
# dayofyear                            0.036130 -0.019724  0.101029  0.996487
# quarter                              0.039358 -0.028640  0.021647  0.971325
# weekofyear                           0.042208 -0.030478  0.070373  0.966367
# value_1dayofyear                     0.107662  0.783179  0.011792 -0.029900
# dayofyear_1d                         0.003180 -0.016283  0.094894  0.996564
# value_7dayofyear                     0.116812  0.895753 -0.051059 -0.021059
# dayofyear_7d                         0.011866 -0.001680  0.062531  0.996590
# business_hour                        0.000081  0.419530  0.000125 -0.000089
# hour_month_cat                       0.229327  0.284717 -0.002752  0.180954
# hour_day_cat                         0.004704  0.029391  0.790468  0.011481
# hour_day_of_week_cat                 0.000066  0.266159 -0.003576  0.003335
# hour_day_of_week_month_cat           0.233310  0.252619 -0.003050  0.180822
# mean_hour_day_of_week_month_value    0.067020  0.921625 -0.006670 -0.023547
# median_hour_day_of_week_month_value  0.064023  0.913786 -0.004671 -0.018232
# mean_value_1dayofyear_value          0.129553  0.997293  0.056231 -0.021931
# median_value_1dayofyear_value        0.129573  0.997279  0.056270 -0.021901
# mean_value_7dayofyear_value          0.101775  0.998946  0.048385 -0.008146
# median_value_7dayofyear_value        0.101769  0.998929  0.048364 -0.008109
#
#                                          hour      year      week  dayofweek  \
# id                                   0.000610  0.969923  0.042208  -0.001706
# value                                0.500412  0.107406 -0.030478  -0.333319
# day                                  0.000269 -0.019940  0.070373   0.004364
# month                               -0.000192 -0.209583  0.966367  -0.004219
# hour                                 1.000000 -0.000028 -0.000176   0.000283
# year                                -0.000028  1.000000 -0.194360  -0.000742
# week                                -0.000176 -0.194360  1.000000  -0.000350
# dayofweek                            0.000283 -0.000742 -0.000350   1.000000
# dayofyear                           -0.000170 -0.208207  0.967591  -0.003812
# quarter                             -0.000253 -0.197344  0.943060  -0.004484
# weekofyear                          -0.000176 -0.194360  1.000000  -0.000350
# value_1dayofyear                     0.501646  0.110861 -0.030789  -0.291246
# dayofyear_1d                        -0.000328 -0.240073  0.973176  -0.011092
# value_7dayofyear                     0.500540  0.119068 -0.021042  -0.336249
# dayofyear_7d                        -0.000289 -0.230721  0.988753  -0.010785
# business_hour                        0.167737 -0.000013 -0.000082   0.000132
# hour_month_cat                       0.082970  0.179325  0.192288   0.003982
# hour_day_cat                         0.032343 -0.014276  0.064385   0.001322
# hour_day_of_week_cat                 0.142624 -0.000765  0.000729  -0.494708
# hour_day_of_week_month_cat           0.011584  0.183307  0.192915  -0.002950
# mean_hour_day_of_week_month_value    0.546909  0.070745 -0.021030  -0.360800
# median_hour_day_of_week_month_value  0.543118  0.066517 -0.015248  -0.360373
# mean_value_1dayofyear_value          0.495727  0.128047 -0.032636  -0.335118
# median_value_1dayofyear_value        0.495785  0.128057 -0.032604  -0.335082
# mean_value_7dayofyear_value          0.497763  0.098824 -0.008464  -0.333967
# median_value_7dayofyear_value        0.497756  0.098809 -0.008428  -0.333936
#
#                                      dayofyear   quarter  ...  hour_month_cat  \
# id                                    0.036130  0.039358  ...        0.229327
# value                                -0.019724 -0.028640  ...        0.284717
# day                                   0.101029  0.021647  ...       -0.002752
# month                                 0.996487  0.971325  ...        0.180954
# hour                                 -0.000170 -0.000253  ...        0.082970
# year                                 -0.208207 -0.197344  ...        0.179325
# week                                  0.967591  0.943060  ...        0.192288
# dayofweek                            -0.003812 -0.004484  ...        0.003982
# dayofyear                             1.000000  0.968377  ...        0.185133
# quarter                               0.968377  1.000000  ...        0.217951
# weekofyear                            0.967591  0.943060  ...        0.192288
# value_1dayofyear                     -0.027772 -0.034526  ...        0.296644
# dayofyear_1d                          1.000000  0.969902  ...        0.172554
# value_7dayofyear                     -0.023975 -0.015115  ...        0.335722
# dayofyear_7d                          1.000000  0.969808  ...        0.126611
# business_hour                        -0.000079 -0.000118  ...        0.013829
# hour_month_cat                        0.185133  0.217951  ...        1.000000
# hour_day_cat                          0.077432  0.014290  ...        0.003809
# hour_day_of_week_cat                  0.003029  0.004102  ...        0.012026
# hour_day_of_week_month_cat            0.184983  0.217831  ...        0.994080
# mean_hour_day_of_week_month_value    -0.022631 -0.028227  ...        0.304038
# median_hour_day_of_week_month_value  -0.017307 -0.024918  ...        0.291176
# mean_value_1dayofyear_value          -0.016190 -0.025375  ...        0.292301
# median_value_1dayofyear_value        -0.016156 -0.025338  ...        0.292325
# mean_value_7dayofyear_value          -0.003115 -0.013554  ...        0.314786
# median_value_7dayofyear_value        -0.003079 -0.013518  ...        0.314829
#
#                                      hour_day_cat  hour_day_of_week_cat  \
# id                                       0.004704              0.000066
# value                                    0.029391              0.266159
# day                                      0.790468             -0.003576
# month                                    0.011481              0.003335
# hour                                     0.032343              0.142624
# year                                    -0.014276             -0.000765
# week                                     0.064385              0.000729
# dayofweek                                0.001322             -0.494708
# dayofyear                                0.077432              0.003029
# quarter                                  0.014290              0.004102
# weekofyear                               0.064385              0.000729
# value_1dayofyear                         0.025068              0.407492
# dayofyear_1d                             0.078292              0.014644
# value_7dayofyear                        -0.040156              0.268025
# dayofyear_7d                             0.040347             -0.002466
# business_hour                            0.005483              0.023896
# hour_month_cat                           0.003809              0.012026
# hour_day_cat                             1.000000              0.000185
# hour_day_of_week_cat                     0.000185              1.000000
# hour_day_of_week_month_cat               0.000834              0.013868
# mean_hour_day_of_week_month_value        0.014000              0.285369
# median_hour_day_of_week_month_value      0.015534              0.285228
# mean_value_1dayofyear_value              0.053844              0.273926
# median_value_1dayofyear_value            0.053868              0.273909
# mean_value_7dayofyear_value              0.053577              0.269396
# median_value_7dayofyear_value            0.053545              0.269483
#
#                                      hour_day_of_week_month_cat  \
# id                                                     0.233310
# value                                                  0.252619
# day                                                   -0.003050
# month                                                  0.180822
# hour                                                   0.011584
# year                                                   0.183307
# week                                                   0.192915
# dayofweek                                             -0.002950
# dayofyear                                              0.184983
# quarter                                                0.217831
# weekofyear                                             0.192915
# value_1dayofyear                                       0.265473
# dayofyear_1d                                           0.171341
# value_7dayofyear                                       0.302609
# dayofyear_7d                                           0.128536
# business_hour                                          0.001853
# hour_month_cat                                         0.994080
# hour_day_cat                                           0.000834
# hour_day_of_week_cat                                   0.013868
# hour_day_of_week_month_cat                             1.000000
# mean_hour_day_of_week_month_value                      0.269450
# median_hour_day_of_week_month_value                    0.257180
# mean_value_1dayofyear_value                            0.262580
# median_value_1dayofyear_value                          0.262593
# mean_value_7dayofyear_value                            0.282975
# median_value_7dayofyear_value                          0.283016
#
#                                      mean_hour_day_of_week_month_value  \
# id                                                            0.067020
# value                                                         0.921625
# day                                                          -0.006670
# month                                                        -0.023547
# hour                                                          0.546909
# year                                                          0.070745
# week                                                         -0.021030
# dayofweek                                                    -0.360800
# dayofyear                                                    -0.022631
# quarter                                                      -0.028227
# weekofyear                                                   -0.021030
# value_1dayofyear                                              0.726841
# dayofyear_1d                                                 -0.023479
# value_7dayofyear                                              0.922016
# dayofyear_7d                                                 -0.036518
# business_hour                                                 0.458923
# hour_month_cat                                                0.304038
# hour_day_cat                                                  0.014000
# hour_day_of_week_cat                                          0.285369
# hour_day_of_week_month_cat                                    0.269450
# mean_hour_day_of_week_month_value                             1.000000
# median_hour_day_of_week_month_value                           0.991744
# mean_value_1dayofyear_value                                   0.920666
# median_value_1dayofyear_value                                 0.920653
# mean_value_7dayofyear_value                                   0.934708
# median_value_7dayofyear_value                                 0.934714
#
#                                      median_hour_day_of_week_month_value  \
# id                                                              0.064023
# value                                                           0.913786
# day                                                            -0.004671
# month                                                          -0.018232
# hour                                                            0.543118
# year                                                            0.066517
# week                                                           -0.015248
# dayofweek                                                      -0.360373
# dayofyear                                                      -0.017307
# quarter                                                        -0.024918
# weekofyear                                                     -0.015248
# value_1dayofyear                                                0.720849
# dayofyear_1d                                                   -0.017139
# value_7dayofyear                                                0.918388
# dayofyear_7d                                                   -0.031819
# business_hour                                                   0.459969
# hour_month_cat                                                  0.291176
# hour_day_cat                                                    0.015534
# hour_day_of_week_cat                                            0.285228
# hour_day_of_week_month_cat                                      0.257180
# mean_hour_day_of_week_month_value                               0.991744
# median_hour_day_of_week_month_value                             1.000000
# mean_value_1dayofyear_value                                     0.912368
# median_value_1dayofyear_value                                   0.912345
# mean_value_7dayofyear_value                                     0.932077
# median_value_7dayofyear_value                                   0.932097
#
#                                      mean_value_1dayofyear_value  \
# id                                                      0.129553
# value                                                   0.997293
# day                                                     0.056231
# month                                                  -0.021931
# hour                                                    0.495727
# year                                                    0.128047
# week                                                   -0.032636
# dayofweek                                              -0.335118
# dayofyear                                              -0.016190
# quarter                                                -0.025375
# weekofyear                                             -0.032636
# value_1dayofyear                                        0.785429
# dayofyear_1d                                           -0.016190
# value_7dayofyear                                        0.894814
# dayofyear_7d                                           -0.009552
# business_hour                                           0.415073
# hour_month_cat                                          0.292301
# hour_day_cat                                            0.053844
# hour_day_of_week_cat                                    0.273926
# hour_day_of_week_month_cat                              0.262580
# mean_hour_day_of_week_month_value                       0.920666
# median_hour_day_of_week_month_value                     0.912368
# mean_value_1dayofyear_value                             1.000000
# median_value_1dayofyear_value                           0.999986
# mean_value_7dayofyear_value                             0.996180
# median_value_7dayofyear_value                           0.996198
#
#                                      median_value_1dayofyear_value  \
# id                                                        0.129573
# value                                                     0.997279
# day                                                       0.056270
# month                                                    -0.021901
# hour                                                      0.495785
# year                                                      0.128057
# week                                                     -0.032604
# dayofweek                                                -0.335082
# dayofyear                                                -0.016156
# quarter                                                  -0.025338
# weekofyear                                               -0.032604
# value_1dayofyear                                          0.785399
# dayofyear_1d                                             -0.016156
# value_7dayofyear                                          0.894814
# dayofyear_7d                                             -0.009537
# business_hour                                             0.415045
# hour_month_cat                                            0.292325
# hour_day_cat                                              0.053868
# hour_day_of_week_cat                                      0.273909
# hour_day_of_week_month_cat                                0.262593
# mean_hour_day_of_week_month_value                         0.920653
# median_hour_day_of_week_month_value                       0.912345
# mean_value_1dayofyear_value                               0.999986
# median_value_1dayofyear_value                             1.000000
# mean_value_7dayofyear_value                               0.996176
# median_value_7dayofyear_value                             0.996194
#
#                                      mean_value_7dayofyear_value  \
# id                                                      0.101775
# value                                                   0.998946
# day                                                     0.048385
# month                                                  -0.008146
# hour                                                    0.497763
# year                                                    0.098824
# week                                                   -0.008464
# dayofweek                                              -0.333967
# dayofyear                                              -0.003115
# quarter                                                -0.013554
# weekofyear                                             -0.008464
# value_1dayofyear                                        0.780514
# dayofyear_1d                                           -0.010704
# value_7dayofyear                                        0.896574
# dayofyear_7d                                           -0.003115
# business_hour                                           0.416394
# hour_month_cat                                          0.314786
# hour_day_cat                                            0.053577
# hour_day_of_week_cat                                    0.269396
# hour_day_of_week_month_cat                              0.282975
# mean_hour_day_of_week_month_value                       0.934708
# median_hour_day_of_week_month_value                     0.932077
# mean_value_1dayofyear_value                             0.996180
# median_value_1dayofyear_value                           0.996176
# mean_value_7dayofyear_value                             1.000000
# median_value_7dayofyear_value                           0.999983
#
#                                      median_value_7dayofyear_value
# id                                                        0.101769
# value                                                     0.998929
# day                                                       0.048364
# month                                                    -0.008109
# hour                                                      0.497756
# year                                                      0.098809
# week                                                     -0.008428
# dayofweek                                                -0.333936
# dayofyear                                                -0.003079
# quarter                                                  -0.013518
# weekofyear                                               -0.008428
# value_1dayofyear                                          0.780541
# dayofyear_1d                                             -0.010747
# value_7dayofyear                                          0.896605
# dayofyear_7d                                             -0.003079
# business_hour                                             0.416395
# hour_month_cat                                            0.314829
# hour_day_cat                                              0.053545
# hour_day_of_week_cat                                      0.269483
# hour_day_of_week_month_cat                                0.283016
# mean_hour_day_of_week_month_value                         0.934714
# median_hour_day_of_week_month_value                       0.932097
# mean_value_1dayofyear_value                               0.996198
# median_value_1dayofyear_value                             0.996194
# mean_value_7dayofyear_value                               0.999983
# median_value_7dayofyear_value                             1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# # Preparing models

# %%
# feats = ["day", "month", "hour", "hour_month_cat", "hour_day_cat", "day_of_week",  

feats = df_all.select_dtypes("number").columns
black_list = ["id", "hour_day_of_week_cat" "hour_day_of_week_cat", "count_zeros_hour_day_of_week_month_cat_value",
             "prob_zeros_hour_day_of_week_month_cat_value", "count_hour_day_of_week_month_cat_value", 
             "count_hour_day_of_week_month_cat_value","quarter", "hour_day_cat", "value", "count_hour_day_of_week_month_value",
             "count_hour_month_value", "count_hour_day_of_week_value", "dayofyear_1d", "dayofweek_1d", "dayofyear_7d"]
             

feats = [x for x in feats if x not in black_list]
feats
# Out:
# ['day',
#  'month',
#  'hour',
#  'year',
#  'week',
#  'dayofweek',
#  'dayofyear',
#  'weekofyear',
#  'value_1dayofyear',
#  'value_7dayofyear',
#  'business_hour',
#  'hour_month_cat',
#  'hour_day_of_week_cat',
#  'hour_day_of_week_month_cat',
#  'mean_hour_day_of_week_month_value',
#  'median_hour_day_of_week_month_value',
#  'mean_value_1dayofyear_value',
#  'median_value_1dayofyear_value',
#  'mean_value_7dayofyear_value',
#  'median_value_7dayofyear_value']

# %%
df_train = df_all[ df_all["value"].notnull() ]
df_test = df_all[ df_all["value"].isnull() ]

X_train = df_train[feats].fillna(-1).values
y_train = df_train["value"].values
X_test = df_test[feats].fillna(-1).values

# %% [markdown]
# # Train and forecast

# %%
#model = DecisionTreeRegressor()
model = xgb.XGBRegressor(max_depth=8, n_estimators=50, random_state=0)
model.fit(X_train, y_train)
df_test["value"] = model.predict(X_test)
# Out:
# <ipython-input-18-adb76fd5a786>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["value"] = model.predict(X_test)

# %%
scores = cross_val_score(model, X_train, y_train, cv=3, scoring="neg_mean_absolute_error")
print("local score: ", np.mean(scores), np.std(scores))
# Out:
# local score:  -207.30260958388718 15.943383583780172

# %% [markdown]
# # To Kaggle

# %%
df_test[ ["id", "value"] ].to_csv("../output/final_result.csv", index=False)
